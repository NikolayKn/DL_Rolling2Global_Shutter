# %%
from para import Parameter
from train import Trainer
import torchvision.utils as vutils
import torch

#if __name__ == '__main__':
    #torch.multiprocessing.set_start_method('spawn')

    

if __name__ == '__main__':
    
    #torch.multiprocessing.set_start_method('spawn', force=True)
    
    para = Parameter().args
    para.threads=0
    para.model='Unet_mini'
    para.data_root='C://Users/Igor.Smirnov\DL'
    para.video=True
    para.resume=True
    para.sace_dir='C://Users/Igor.Smirnov/DL/RSCD/experiment/'
    para.resume=False
    #para.resume_file='C://Users/Igor.Smirnov/DL/RSCD/experiment/2023_05_26_00_58_44_Unet_mini_rscd_lmdb/checkpoint.pth.tar'
    para.test_checkpoint=None
    para.test_save_dir=None
    para.batch_size=4
    para.test_only=None
    para.end_epoch=5
    para.test_checkpoint=None
    #para.test_checkpoint='C://Users/Igor.Smirnov/DL/RSCD/experiment/2023_05_25_23_56_54_Unet_mini_rscd_lmdb/checkpoint.pth.tar'
    
    trainer = Trainer(para)
    trainer.run()
# Out:
# 2023/05/26, 01:21:27 - recording parameters ...
# description: develop
# seed: 39
# threads: 0
# cpu: False
# num_gpus: 1
# resume: True
# resume_file: C://Users/Igor.Smirnov/DL/RSCD/experiment/2023_05_26_00_58_44_Unet_mini_rscd_lmdb/checkpoint.pth.tar
# data_root: C://Users/Igor.Smirnov\DL
# dataset: rscd_lmdb
# save_dir: ./experiment/
# frames: 3
# patch_size: [256, 256]
# model: Unet_mini
# future_frames: 1
# past_frames: 1
# activation: relu
# loss: 10*L1_Charbonnier_loss_color|1*Perceptual|0.1*Variation
# metrics: PSNR
# optimizer: Adam
# lr: 0.0003
# lr_scheduler: cosine
# batch_size: 4
# milestones: [200, 400]
# decay_gamma: 0.5
# start_epoch: 1
# end_epoch: 400
# test_only: None
# test_frames: 3
# test_save_dir: None
# video: True
# sace_dir: C://Users/Igor.Smirnov/DL/RSCD/experiment/
# test_checkpoint: None
# time: 2023-05-26 01:21:27.002539
#
# 2023/05/26, 01:21:27 - building Unet_mini model ...
# ...

# %%
para
# Out:
# Namespace(description='develop', seed=39, threads=0, cpu=False, num_gpus=1, resume=False, resume_file='', data_root='/home/zhong/Dataset/', dataset='rscd_lmdb', save_dir='./experiment/', frames=3, patch_size=[256, 256], model='Unet_mini', future_frames=1, past_frames=1, activation='relu', loss='10*L1_Charbonnier_loss_color|1*Perceptual|0.1*Variation', metrics='PSNR', optimizer='Adam', lr=0.0003, lr_scheduler='cosine', batch_size=2, milestones=[200, 400], decay_gamma=0.5, start_epoch=1, end_epoch=400, test_only=False, test_frames=3, test_save_dir=None, test_checkpoint='/home/zhong/Project/ESTRNN/ESTRNN/experiment/2020_09_21_00_59_16_ESTRNN_gopro_ds/model_best.path.tar', video=False, time=datetime.datetime(2023, 5, 25, 21, 58, 0, 345884))

# %%
trainer.para
# Out:
# Namespace(description='develop', seed=39, threads=0, cpu=False, num_gpus=1, resume=True, resume_file='C://Users/Igor.Smirnov/DL/RSCD/experiment/2023_05_26_00_58_44_Unet_mini_rscd_lmdb/checkpoint.pth.tar', data_root='C://Users/Igor.Smirnov\\DL', dataset='rscd_lmdb', save_dir='./experiment/', frames=3, patch_size=[256, 256], model='Unet_mini', future_frames=1, past_frames=1, activation='relu', loss='10*L1_Charbonnier_loss_color|1*Perceptual|0.1*Variation', metrics='PSNR', optimizer='Adam', lr=0.0003, lr_scheduler='cosine', batch_size=4, milestones=[200, 400], decay_gamma=0.5, start_epoch=5, end_epoch=400, test_only=None, test_frames=3, test_save_dir=None, video=True, sace_dir='C://Users/Igor.Smirnov/DL/RSCD/experiment/', test_checkpoint=None, time=datetime.datetime(2023, 5, 26, 1, 21, 27, 2539))

# %%
trainer.para.test_only=True
trainer.para.test_checkpoint='C://Users/Igor.Smirnov/DL/RSCD/experiment/2023_05_26_01_21_27_Unet_mini_rscd_lmdb/model_best.pth.tar'

trainer.run()
# Out:
# 2023/05/26, 07:54:24 - recording parameters ...
# description: develop
# seed: 39
# threads: 0
# cpu: False
# num_gpus: 1
# resume: True
# resume_file: C://Users/Igor.Smirnov/DL/RSCD/experiment/2023_05_26_00_58_44_Unet_mini_rscd_lmdb/checkpoint.pth.tar
# data_root: C://Users/Igor.Smirnov\DL
# dataset: rscd_lmdb
# save_dir: ./experiment/
# frames: 3
# patch_size: [256, 256]
# model: Unet_mini
# future_frames: 1
# past_frames: 1
# activation: relu
# loss: 10*L1_Charbonnier_loss_color|1*Perceptual|0.1*Variation
# metrics: PSNR
# optimizer: Adam
# lr: 0.0003
# lr_scheduler: cosine
# batch_size: 4
# milestones: [200, 400]
# decay_gamma: 0.5
# start_epoch: 5
# end_epoch: 400
# test_only: True
# test_frames: 3
# test_save_dir: None
# video: True
# sace_dir: C://Users/Igor.Smirnov/DL/RSCD/experiment/
# test_checkpoint: C://Users/Igor.Smirnov/DL/RSCD/experiment/2023_05_26_01_21_27_Unet_mini_rscd_lmdb/model_best.pth.tar
# time: 2023-05-26 07:54:24.019906
#
# ...

# %%
trainer.para.start_epoch=3
trainer.para.end_epoch=3
trainer.para.video=True
trainer.para.resume=True
trainer.para.sace_dir='C://Users/Igor.Smirnov/DL/RSCD/experiment/'
trainer.para.resume_file='C://Users/Igor.Smirnov/DL/RSCD/experiment/2023_05_25_22_10_54_Unet_mini_rscd_lmdb/checkpoint.pth.tar'

# %%
if __name__ == '__main__':
    
    #torch.multiprocessing.set_start_method('spawn', force=True)
    
    para = Parameter().args
    para.threads=0
    para.model='Unet_mini'
    para.data_root='C://Users/Igor.Smirnov\DL'
    para.video=True
    para.resume=True
    para.sace_dir='C://Users/Igor.Smirnov/DL/RSCD/experiment/'
    para.resume=False
    #para.resume_file='C://Users/Igor.Smirnov/DL/RSCD/experiment/2023_05_26_00_58_44_Unet_mini_rscd_lmdb/checkpoint.pth.tar'
    para.test_checkpoint=None
    para.test_save_dir=None
    para.batch_size=4
    para.test_only=None
    para.end_epoch=5
    para.test_checkpoint=None
    #para.test_checkpoint='C://Users/Igor.Smirnov/DL/RSCD/experiment/2023_05_25_23_56_54_Unet_mini_rscd_lmdb/checkpoint.pth.tar'
    
    trainer = Trainer(para)
    trainer.run()
# Out:
# 2023/05/26, 08:21:28 - recording parameters ...
# description: develop
# seed: 39
# threads: 0
# cpu: False
# num_gpus: 1
# resume: False
# resume_file: ./
# data_root: C://Users/Igor.Smirnov\DL
# dataset: rscd_lmdb
# save_dir: ./experiment/
# frames: 3
# patch_size: [256, 256]
# model: Unet_mini
# future_frames: 1
# past_frames: 1
# activation: relu
# loss: 10*L1_Charbonnier_loss_color|1*Perceptual|0.1*Variation
# metrics: PSNR
# optimizer: Adam
# lr: 0.0003
# lr_scheduler: cosine
# batch_size: 4
# milestones: [200, 400]
# decay_gamma: 0.5
# start_epoch: 1
# end_epoch: 5
# test_only: None
# test_frames: 3
# test_save_dir: None
# video: True
# sace_dir: C://Users/Igor.Smirnov/DL/RSCD/experiment/
# test_checkpoint: None
# time: 2023-05-26 08:21:28.358717
#
# 2023/05/26, 08:21:28 - building Unet_mini model ...
#
# 2023/05/26, 08:21:29 - loading rscd_lmdb dataloader ...
#
# 2023/05/26, 08:21:29 - [Epoch 1 / lr 3.00e-04]
# ...
